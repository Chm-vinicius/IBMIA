# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#LR_Loader_Cost">Create a Linear Regression Object, Data Loader and Criterion Function</a></li>
#     <li><a href="#LR_Hyper">Different learning rates and Data Structures to Store results for Different Hyperparameters</a></li>
#     <li><a href="#Model">Train different modules for different Hyperparameters</a></li>
#     <li><a href="#Result">View Results</a></li>
# </ul>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2>

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2>

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Train different models  for different Hyperparameters</h2>

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Result">View the Results</h2>

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[2.5815022]
#  [2.500059 ]
#  [2.4186153]]
# 1 [[5.7576666]
#  [5.637576 ]
#  [5.5174847]]
# 2 [[6.624483 ]
#  [6.4894333]
#  [6.3543835]]
# 3 [[14.44177 ]
#  [14.008099]
#  [13.574426]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

#Type your code here: 

losst = []

for x,y in trainloader:
    yhat2 = good_model(x)
    print(yhat2)
    losst.append(y-yhat2)

print(losst)
# Out:
# tensor([[14.4418]], grad_fn=<AddmmBackward0>)
# tensor([[14.0081]], grad_fn=<AddmmBackward0>)
# tensor([[13.5744]], grad_fn=<AddmmBackward0>)
# tensor([[13.1408]], grad_fn=<AddmmBackward0>)
# tensor([[12.7071]], grad_fn=<AddmmBackward0>)
# tensor([[12.2734]], grad_fn=<AddmmBackward0>)
# tensor([[11.8397]], grad_fn=<AddmmBackward0>)
# tensor([[11.4061]], grad_fn=<AddmmBackward0>)
# tensor([[10.9724]], grad_fn=<AddmmBackward0>)
# tensor([[10.5387]], grad_fn=<AddmmBackward0>)
# tensor([[10.1050]], grad_fn=<AddmmBackward0>)
# tensor([[9.6714]], grad_fn=<AddmmBackward0>)
# tensor([[9.2377]], grad_fn=<AddmmBackward0>)
# tensor([[8.8040]], grad_fn=<AddmmBackward0>)
# tensor([[8.3704]], grad_fn=<AddmmBackward0>)
# tensor([[7.9367]], grad_fn=<AddmmBackward0>)
# tensor([[7.5030]], grad_fn=<AddmmBackward0>)
# tensor([[7.0693]], grad_fn=<AddmmBackward0>)
# tensor([[6.6357]], grad_fn=<AddmmBackward0>)
# tensor([[6.2020]], grad_fn=<AddmmBackward0>)
# tensor([[5.7683]], grad_fn=<AddmmBackward0>)
# tensor([[5.3347]], grad_fn=<AddmmBackward0>)
# tensor([[4.9010]], grad_fn=<AddmmBackward0>)
# tensor([[4.4673]], grad_fn=<AddmmBackward0>)
# tensor([[4.0336]], grad_fn=<AddmmBackward0>)
# tensor([[3.6000]], grad_fn=<AddmmBackward0>)
# tensor([[3.1663]], grad_fn=<AddmmBackward0>)
# tensor([[2.7326]], grad_fn=<AddmmBackward0>)
# tensor([[2.2989]], grad_fn=<AddmmBackward0>)
# tensor([[1.8653]], grad_fn=<AddmmBackward0>)
# tensor([[1.4316]], grad_fn=<AddmmBackward0>)
# tensor([[0.9979]], grad_fn=<AddmmBackward0>)
# tensor([[0.5643]], grad_fn=<AddmmBackward0>)
# tensor([[0.1306]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3031]], grad_fn=<AddmmBackward0>)
# tensor([[-0.7368]], grad_fn=<AddmmBackward0>)
# tensor([[-1.1704]], grad_fn=<AddmmBackward0>)
# tensor([[-1.6041]], grad_fn=<AddmmBackward0>)
# tensor([[-2.0378]], grad_fn=<AddmmBackward0>)
# tensor([[-2.4714]], grad_fn=<AddmmBackward0>)
# tensor([[-2.9051]], grad_fn=<AddmmBackward0>)
# tensor([[-3.3388]], grad_fn=<AddmmBackward0>)
# tensor([[-3.7725]], grad_fn=<AddmmBackward0>)
# tensor([[-4.2061]], grad_fn=<AddmmBackward0>)
# tensor([[-4.6398]], grad_fn=<AddmmBackward0>)
# tensor([[-5.0735]], grad_fn=<AddmmBackward0>)
# tensor([[-5.5072]], grad_fn=<AddmmBackward0>)
# tensor([[-5.9408]], grad_fn=<AddmmBackward0>)
# tensor([[-6.3745]], grad_fn=<AddmmBackward0>)
# tensor([[-6.8082]], grad_fn=<AddmmBackward0>)
# tensor([[-7.2418]], grad_fn=<AddmmBackward0>)
# tensor([[-7.6755]], grad_fn=<AddmmBackward0>)
# tensor([[-8.1092]], grad_fn=<AddmmBackward0>)
# tensor([[-8.5429]], grad_fn=<AddmmBackward0>)
# tensor([[-8.9765]], grad_fn=<AddmmBackward0>)
# tensor([[-9.4102]], grad_fn=<AddmmBackward0>)
# tensor([[-9.8439]], grad_fn=<AddmmBackward0>)
# tensor([[-10.2776]], grad_fn=<AddmmBackward0>)
# tensor([[-10.7112]], grad_fn=<AddmmBackward0>)
# tensor([[-11.1449]], grad_fn=<AddmmBackward0>)
# [tensor([[-14.4418]], grad_fn=<SubBackward0>), tensor([[-4.1863]], grad_fn=<SubBackward0>), tensor([[-4.2069]], grad_fn=<SubBackward0>), tensor([[-3.9008]], grad_fn=<SubBackward0>), tensor([[-3.6924]], grad_fn=<SubBackward0>), tensor([[-3.7100]], grad_fn=<SubBackward0>), tensor([[-3.5588]], grad_fn=<SubBackward0>), tensor([[-3.4433]], grad_fn=<SubBackward0>), tensor([[-3.4535]], grad_fn=<SubBackward0>), tensor([[-3.0678]], grad_fn=<SubBackward0>), tensor([[-3.3050]], grad_fn=<SubBackward0>), tensor([[-2.9685]], grad_fn=<SubBackward0>), tensor([[-2.8404]], grad_fn=<SubBackward0>), tensor([[-2.6938]], grad_fn=<SubBackward0>), tensor([[-2.6040]], grad_fn=<SubBackward0>), tensor([[-2.2775]], grad_fn=<SubBackward0>), tensor([[-2.3742]], grad_fn=<SubBackward0>), tensor([[-2.0364]], grad_fn=<SubBackward0>), tensor([[-2.1325]], grad_fn=<SubBackward0>), tensor([[-2.0299]], grad_fn=<SubBackward0>), tensor([[-1.6816]], grad_fn=<SubBackward0>), tensor([[-1.6881]], grad_fn=<SubBackward0>), tensor([[-1.5659]], grad_fn=<SubBackward0>), tensor([[-1.3841]], grad_fn=<SubBackward0>), tensor([[-1.2460]], grad_fn=<SubBackward0>), tensor([[-1.2145]], grad_fn=<SubBackward0>), tensor([[-0.8787]], grad_fn=<SubBackward0>), tensor([[-0.7523]], grad_fn=<SubBackward0>), tensor([[-0.7522]], grad_fn=<SubBackward0>), tensor([[-0.3736]], grad_fn=<SubBackward0>), tensor([[-0.4113]], grad_fn=<SubBackward0>), tensor([[-0.2095]], grad_fn=<SubBackward0>), tensor([[-0.1166]], grad_fn=<SubBackward0>), tensor([[-0.1894]], grad_fn=<SubBackward0>), tensor([[0.0741]], grad_fn=<SubBackward0>), tensor([[0.3497]], grad_fn=<SubBackward0>), tensor([[0.3976]], grad_fn=<SubBackward0>), tensor([[0.5668]], grad_fn=<SubBackward0>), tensor([[0.5558]], grad_fn=<SubBackward0>), tensor([[0.8110]], grad_fn=<SubBackward0>), tensor([[0.7804]], grad_fn=<SubBackward0>), tensor([[1.3185]], grad_fn=<SubBackward0>), tensor([[1.0868]], grad_fn=<SubBackward0>), tensor([[1.2448]], grad_fn=<SubBackward0>), tensor([[1.4842]], grad_fn=<SubBackward0>), tensor([[1.4693]], grad_fn=<SubBackward0>), tensor([[1.7460]], grad_fn=<SubBackward0>), tensor([[1.8350]], grad_fn=<SubBackward0>), tensor([[1.8043]], grad_fn=<SubBackward0>), tensor([[2.2317]], grad_fn=<SubBackward0>), tensor([[27.2418]], grad_fn=<SubBackward0>), tensor([[27.6755]], grad_fn=<SubBackward0>), tensor([[28.1092]], grad_fn=<SubBackward0>), tensor([[28.5429]], grad_fn=<SubBackward0>), tensor([[28.9765]], grad_fn=<SubBackward0>), tensor([[2.9751]], grad_fn=<SubBackward0>), tensor([[3.0194]], grad_fn=<SubBackward0>), tensor([[3.0390]], grad_fn=<SubBackward0>), tensor([[3.2813]], grad_fn=<SubBackward0>), tensor([[3.4523]], grad_fn=<SubBackward0>)]

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# for x, y in trainloader:
#     print("yhat= ", model(x),"y", y)
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
