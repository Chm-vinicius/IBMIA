# %%
import keras
import pandas as pd

# %%
df = pd.read_csv("concrete_data.csv")

df.head
# Out:
# <bound method NDFrame.head of       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df.fillna('0')
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
Y = df.pop('Strength')
X = df

# %%
def concrete_model():
    model = keras.Sequential()
    model.add(keras.layers.Input(shape=(8,)))
    model.add(keras.layers.Normalization())
    model.add(keras.layers.Dense(10, activation='relu'))
    model.add(keras.layers.Dense(10, activation='relu'))
    model.add(keras.layers.Dense(10, activation='relu'))
    
    model.compile(optimizer="adam", loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.mean_squared_error()])
    return model

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
model = concrete_model()

model.fit(X_train, Y_train, epochs=50)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4465.2324 - mean_squared_error: 4465.2324
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1985.8655 - mean_squared_error: 1985.8655
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1281.2719 - mean_squared_error: 1281.2719
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1021.9485 - mean_squared_error: 1021.9485
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 939.0396 - mean_squared_error: 939.0396
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 841.8386 - mean_squared_error: 841.8386
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 833.6784 - mean_squared_error: 833.6784
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 801.6881 - mean_squared_error: 801.6881
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 792.9838 - mean_squared_error: 792.9838
# Epoch 10/50
# ...

# %%
scores = model.evaluate(X_test, Y_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 711.3582 - mean_squared_error: 711.3582

# %%
def iterate(model):
    scores = []
    for i in range(50):
        model.fit(X_train, Y_train, epochs=50)
        result = model.evaluate(X_test, Y_test)
        scores.append(result[1])
    return scores

# %%
import numpy as np

scores = iterate(model)

mean = np.mean(scores)
std = np.std(scores)

print(mean, std)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 707.4319 - mean_squared_error: 707.4319
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 675.5713 - mean_squared_error: 675.5713
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 702.7359 - mean_squared_error: 702.7359
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 696.3610 - mean_squared_error: 696.3610
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 709.2189 - mean_squared_error: 709.2189
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 689.3958 - mean_squared_error: 689.3958
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 704.2036 - mean_squared_error: 704.2036
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 693.4973 - mean_squared_error: 693.4973
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 725.6281 - mean_squared_error: 725.6281
# Epoch 10/50
# ...

# %% [markdown]
# ### Mean of mean squared error of Steb B 706 compared to this 390 is significantly smaller
